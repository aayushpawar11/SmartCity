# %%
# Load incident data from the provided JSON file
import json

with open('/tmp/sphinx_oij4f7n4.json', 'r') as f:
    incident = json.load(f)

incident
# Out:
# {'event_type': 'unknown',
#  'confidence': 0.3,
#  'vehicles_detected': 0,
#  'blocked_lanes': 0,
#  'severity': 'low',
#  'description': 'Unable to classify — Gemini unavailable',
#  'lat': 33.91454,
#  'lon': -84.286824,
#  'notification': 'Incident detected ahead near your route.',
#  'image_path': 'frames/frame_3.jpg',
#  'id': 3,
#  'similar_count': 3,
#  'estimated_clearance': 15.0,
#  'is_false_positive': True}
